# %%
import import_ipynb
import my_other_notebook as loner_notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import import_ipynb
#       2 import my_other_notebook as loner_notebook
#
# ModuleNotFoundError: No module named 'import_ipynb'
